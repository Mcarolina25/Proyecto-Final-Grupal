# %%
from funciones import insert_into_table_usuarios

# %%
# Read a Parquet file into a DataFrame
path_file = r"C:\Data\Yelp\user.parquet"
insert_into_table_usuarios(path_file)
# Out:
# Data inserted successfully into the table 'user_yelp'!

# %%
df.size
# Out:
# 46323134

# %%
df_no_duplicates = df.drop_duplicates()

# %%
df_no_duplicates.size
# Out:
# 43733734

# %%
df_no_duplicates.columns
# Out:
# Index(['user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny',
#        'cool', 'elite', 'friends', 'fans', 'average_stars', 'compliment_hot',
#        'compliment_more', 'compliment_profile', 'compliment_cute',
#        'compliment_list', 'compliment_note', 'compliment_plain',
#        'compliment_cool', 'compliment_funny', 'compliment_writer',
#        'compliment_photos'],
#       dtype='object')

# %%
# Database connection details
user = 'postgres'
password = '98020927'
host = 'localhost'
port = '5432'
database = 'ADSAC'

# Create the connection string
engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}')

# %%
table_name = 'user_yelp'
df_no_duplicates.to_sql(table_name, engine, if_exists='append', index=False)

print(f"Data inserted successfully into the table '{table_name}'!")
# Out:
# Data inserted successfully into the table 'user_yelp'!
