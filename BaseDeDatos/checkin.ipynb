# %%
from funciones import insert_into_table_checkin

# %%
path_file = r'C:\Data\Yelp\checkin.json'  # Reemplaza con la ruta real a tu directorio
insert_into_table_checkin(path_file)
# Out:
# Data inserted successfully into the table 'checkin'!
