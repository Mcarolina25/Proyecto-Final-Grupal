# %%
from funciones import insert_into_table_business

# %%
path_file = r"C:\Data\Yelp\business.pkl"
insert_into_table_business(path_file)
# Out:
# Data inserted successfully into the table 'business'!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 path_file = r"C:\Data\Yelp\business.pkl"
# ----> 2 insert_into_table_business(path_file)
#
# File c:\DataScience\Repositorio\ProyectoFinal\Proyecto-Final-Grupal\BaseDeDatos\funciones.py:202, in insert_into_table_business(path_file)
#     198 insertar_sql(df, 'business', engine, type_operation, index_value)
#     199 #except:
#     200 #    print("fails with: :'( )")
# --> 202 return df_final
#
# NameError: name 'df_final' is not defined
