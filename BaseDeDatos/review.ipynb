# %%
from funciones import insert_into_table_business
path_file = r"C:\Data\Yelp\business.pkl"
df_business = insert_into_table_business(path_file)
# Out:
# Data inserted successfully into the table 'business'!

# %%
from funciones import insert_into_table_review

# %%
path_dir = r'C:\Data\Yelp\review.json'  # Reemplaza con la ruta real a tu directorio
df_review = insert_into_table_review(path_dir)

# %%
df_review.shape
# Out:
# (6990280, 9)

# %%
from funciones import get_connection_engine
from sqlalchemy import create_engine
from sqlalchemy.sql import text
import psycopg2
from funciones import insertar_sql

# %%
df_breview = df_review[df_review['business_id'].isin(df_business['business_id'])]

# %%
df_breview.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars', 'useful', 'funny',
#        'cool', 'text', 'date'],
#       dtype='object')

# %%
engine = get_connection_engine()
type_operation= 'append'
index_value = False
insertar_sql(df_breview, 'review', engine, type_operation, index_value)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File c:\python\Lib\site-packages\sqlalchemy\engine\base.py:2118, in Connection._exec_insertmany_context(self, dialect, context)
#    2117     else:
# -> 2118         dialect.do_execute(
#    2119             cursor,
#    2120             sub_stmt,
#    2121             sub_params,
#    2122             context,
#    2123         )
#    2125 except BaseException as e:
#
# File c:\python\Lib\site-packages\sqlalchemy\engine\default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# UndefinedColumn: no existe la columna «text» en la relación «review»
# LINE 1: ...user_id, business_id, stars, useful, funny, cool, text, date...
# ...

# %%
df_breview
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw    3.0       0      0     0
# 1        7ATYjTIgM3jUlt4UM3IypQ    5.0       1      0     1
# 2        YjUWPpI6HXG530lwP-fb2A    3.0       0      0     0
# ...

# %%
df_breview.head(2)
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
#
#    stars  useful  funny  cool  \
# 0    3.0       0      0     0
# 1    5.0       1      0     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data

grouped = df_breview.groupby('business_id').size().reset_index(name='Count')

# %%
df_business
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# ...

# %%
# Add 'Age' column from df2 to df1 by matching 'ID'
grouped['business'] = grouped['business_id'].map(df_business.set_index('business_id')['name'])

# %%
sorted_df_asc = grouped.sort_values(by='Count', ascending=False)

# %%
print("Descending Order:")
print(sorted_df_asc.head(10))

graph = sorted_df_asc.head(10)
# Out:
# Descending Order:
#                    business_id  Count                            business
# 88202   _ab50qdWOk0DdB6XOrBitw   7673                   Acme Oyster House
# 90484   ac1AeYqs8Z4_e2X5M3if2A   7516                        Oceana Grill
# 41309   GXFMD0Z4jEVZBCsbPf4CTQ   6160  Hattie B’s Hot Chicken - Nashville
# 147782  ytynqOUb3hjKeJfRj5Tshw   5778             Reading Terminal Market
# 122423  oBNrLz4EDhiscSlbOl8uAw   5264          Ruby Slipper - New Orleans
# 108930  iSRTaT9WngzB8JJ2YKJUig   5254                 Mother's Restaurant
# 76060   VQcCL9PiNL_wkGf-uF3fjg   5146                         Royal House
# 87319   _C7QiQQc47AOEv4PE3Kong   4969                  Commander's Palace
# 40540   GBTPC53ZrG1ZBY3DT8Mbcw   4661                                Luke
# 18068   6a4gLLFSgr-Q6CZXDLzBGQ   4480                              Cochon

# %%
# Create the Seaborn scatterplot
sns.set(style="whitegrid")  # Set the style of the plot
plt.figure(figsize=(13, 5))
sns.scatterplot(x=graph['business'], y=graph['Count'], color='blue', marker='o')

# Add titles and labels

plt.xticks(rotation=20) 
plt.title("Simple Seaborn Scatter Plot")
plt.xlabel("Negocios")
plt.ylabel("Conteo")

# Show the graph
plt.show()

# %%
# Add 'Age' column from df2 to df1 by matching 'ID'
#grouped_stars = df_breview.groupby('business_id').size().reset_index(name='stars')
result = df_breview.groupby(['business_id'])['stars'].count()

# %%
# Convert Series to DataFrame with index as a column
df_result = result.reset_index()

# Rename columns for clarity
df_result.columns = ['business_id', 'Values']

# Display the DataFrame
print(df_result)
# Out:
#                    business_id  Values
# 0       ---kPU91CF4Lq2-WlRu9Lw      24
# 1       --0iUa4sNDFiZFrAdIWhZQ      14
# 2       --30_8IhuyMHbSOcNWd6DQ       9
# 3       --7PUidqRWpRSpXebiyxTg      12
# 4       --7jw19RH9JKXgFohspgQw      13
# ...                        ...     ...
# 150341  zznZqH9CiAznbkV6fXyHWA      12
# 150342  zztOG2cKm87I6Iw_tleZsQ       6
# 150343  zzu6_r3DxBJuXcjnOYVdTw       8
# 150344  zzw66H6hVjXQEt0Js3Mo4A       5
# 150345  zzyx5x0Z7xXWWvWnZFuxlQ       8
#
# [150346 rows x 2 columns]

# %%
df_result['business'] = df_result['business_id'].map(df_business.set_index('business_id')['name'])

# %%
df_result
# Out:
#                    business_id  Values  \
# 0       ---kPU91CF4Lq2-WlRu9Lw      24
# 1       --0iUa4sNDFiZFrAdIWhZQ      14
# 2       --30_8IhuyMHbSOcNWd6DQ       9
# 3       --7PUidqRWpRSpXebiyxTg      12
# 4       --7jw19RH9JKXgFohspgQw      13
# ...                        ...     ...
# 150341  zznZqH9CiAznbkV6fXyHWA      12
# 150342  zztOG2cKm87I6Iw_tleZsQ       6
# 150343  zzu6_r3DxBJuXcjnOYVdTw       8
# 150344  zzw66H6hVjXQEt0Js3Mo4A       5
# 150345  zzyx5x0Z7xXWWvWnZFuxlQ       8
#
#                                                business
# 0                                     Frankie's Raw Bar
# 1                          Pupuseria Y Restaurant Melba
# 2                                         Action Karate
# 3                            Humpty's Family Restaurant
# 4       McIlwain Family Dentistry & Ahrens Orthodontics
# ...                                                 ...
# 150341                                   Que Pasta Nola
# ...

# %%
print("Descending Order:")
print(grouped_stars.head(10))

graph = grouped_stars.head(10)
# Out:
# Descending Order:
#               business_id  stars  \
# 0  ---kPU91CF4Lq2-WlRu9Lw     24
# 1  --0iUa4sNDFiZFrAdIWhZQ     14
# 2  --30_8IhuyMHbSOcNWd6DQ      9
# 3  --7PUidqRWpRSpXebiyxTg     12
# 4  --7jw19RH9JKXgFohspgQw     13
# 5  --8IbOsAAxjKRoYsBFL-PA     27
# 6  --9osgUCSDUWUkoTLdvYhQ     30
# 7  --ARBQr1WMsTWiwOKOj-FQ     23
# 8  --FWWsIwxRwuw9vIMImcQg      8
# 9  --FcbSxK1AoEtEAxOgBaCw     42
#
#                                           business
# 0                                Frankie's Raw Bar
# 1                     Pupuseria Y Restaurant Melba
# 2                                    Action Karate
# 3                       Humpty's Family Restaurant
# 4  McIlwain Family Dentistry & Ahrens Orthodontics
# 5                         The Original Italian Pie
# 6                                 Will You Escape?
# 7                                  Traveling Corks
# 8                Blue River Canyon Day Spa & Store
# 9                                 Victory Car Wash
