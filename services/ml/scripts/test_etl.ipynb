# %%
# Iniciamos con la carga de datos para su revision:
# La data está alojada en un archivo json que contiene la metadata de los sitios de Google
# Los metadatos estan organizados por filas donde cada una es un elemento json que contiene una lista de diccionarios
# con la información de cada sitio
import json
import pandas as pd
import sys
sys.path.append('/Users/usuario/Documents/PF_Henry/Proyecto-Final-Grupal')
from functions import *

opciones_impresion() # Invocamos la función para mejorar la impresion y que no se recorte la información al imprimir.

ruta = '/Users/usuario/Documents/PF_Henry/Proyecto-Final-Grupal/Data/Google/metadata-sitios/11.json'
lista = []

with open(ruta, 'r') as file:
    for line in file:
        line = line.strip()  # Elimina espacios y saltos de línea
        if line:  # Evita procesar líneas vacías
            try:
                registro = json.loads(line)
                lista.append(registro)
            except json.JSONDecodeError as e:
                print(f"Error al decodificar una línea: {e}")

df = pd.DataFrame(lista)
print(validar_df(df))
print(df.head(10))
# Out:
#                  Tipo de Dato Int     Int64 Float   Bool DateT Str     Ctgory Nulos   No_Nulos Únicos  Ceros Vacíos (string) Skewness  Kurtosis  Media      Desviación_Std Moda        Mínimo      Q1_25%     Q2_50%     Q3_75%     Máximo     Negativos IQR        %OutL_IQR LowerBound  UpperBound Z-Score    %OutL_Z_Thresh
# name               object           0  0          0  0    0     274999  NaN         2  274999   222437  NaN   NaN                  NaN       NaN        NaN         NaN            NaN         NaN        NaN        NaN        NaN        NaN     NaN          NaN    NaN            NaN        NaN        NaN    NaN
# address            object           0  0          0  0    0     270246  NaN      4755  270246   270200  NaN   NaN                  NaN       NaN        NaN         NaN            NaN         NaN        NaN        NaN        NaN        NaN     NaN          NaN    NaN            NaN        NaN        NaN    NaN
# ...

# %%
# Cargamos archivo pkl y lo convertimos a DataFrame para luego guardarlo como json
df = pd.read_pickle('/Users/usuario/Documents/PF_Henry/Proyecto-Final-Grupal/BigData/Yelp/business.pkl')
# Guardamos el archivo como csv
df.to_csv('/Users/usuario/Documents/PF_Henry/Proyecto-Final-Grupal/BigData/Yelp/business.csv', index=False)
# Ahora cargamos este csv y lo convertimos a json
df = pd.read_csv('/Users/usuario/Documents/PF_Henry/Proyecto-Final-Grupal/BigData/Yelp/business.csv')
df.to_json('/Users/usuario/Documents/PF_Henry/Proyecto-Final-Grupal/BigData/Yelp/business.json', orient='records', lines=True)
# Out:
# /var/folders/78/5lwff5710n349fmq7y5ycwgc0000gn/T/ipykernel_37724/664812643.py:6: DtypeWarning: Columns (14,15,16,17,18,19,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/usuario/Documents/PF_Henry/Proyecto-Final-Grupal/BigData/Yelp/business.csv')

# %%
# ahora cargamos archivo .parquet y lo guardamos como json
df = pd.read_parquet('/Users/usuario/Documents/PF_Henry/Proyecto-Final-Grupal/BigData/Yelp/user.parquet')
df.to_json('/Users/usuario/Documents/PF_Henry/Proyecto-Final-Grupal/BigData/Yelp/user.json', orient='records', lines=True)
